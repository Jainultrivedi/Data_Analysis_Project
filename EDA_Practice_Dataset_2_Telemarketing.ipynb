# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("EDA_Practice_Dataset_2_Telemarketing.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Call_ID     100000 non-null  int64
#  1   Sale        99968 non-null   object
#  2   Agent_ID    97685 non-null   object
#  3   Age         100000 non-null  int64
#  4   Product_ID  100000 non-null  int64
#  5   Timezone    100000 non-null  int64
#  6   Phone_code  99972 non-null   float64
#  7   First_Name  99318 non-null   object
#  8   Last_Name   99319 non-null   object
#  9   Area_Code   99540 non-null   object
#  10  Gender      100000 non-null  object
#  11  Call_Count  100000 non-null  int64
# dtypes: float64(1), int64(5), object(6)
# memory usage: 9.2+ MB

# %%
df.describe()
# Out:
#             Call_ID            Age     Product_ID       Timezone  Phone_code  \
# count  1.000000e+05  100000.000000  100000.000000  100000.000000     99972.0
# mean   9.562981e+06      52.558530     147.216690       1.999420        37.0
# std    4.618927e+05      16.144553       2.182815       0.034054         0.0
# min    8.432514e+06      25.000000     142.000000       0.000000        37.0
# 25%    9.230592e+06      39.000000     146.000000       2.000000        37.0
# 50%    9.527831e+06      53.000000     147.000000       2.000000        37.0
# 75%    9.919197e+06      66.000000     149.000000       2.000000        37.0
# max    1.047664e+07      80.000000     151.000000       2.000000        37.0
#
#          Call_Count
# count  100000.00000
# mean        3.26866
# std         2.96882
# min         1.00000
# 25%         1.00000
# 50%         2.00000
# 75%         4.00000
# max        55.00000

# %%
df.dtypes
# Out:
# Call_ID         int64
# Sale           object
# Agent_ID       object
# Age             int64
# Product_ID      int64
# Timezone        int64
# Phone_code    float64
# First_Name     object
# Last_Name      object
# Area_Code      object
# Gender         object
# Call_Count      int64
# dtype: object

# %%
df["Call_ID"]=df["Call_ID"].astype(object)
df.dtypes
# Out:
# Call_ID        object
# Sale           object
# Agent_ID       object
# Age             int64
# Product_ID      int64
# Timezone        int64
# Phone_code    float64
# First_Name     object
# Last_Name      object
# Area_Code      object
# Gender         object
# Call_Count      int64
# dtype: object

# %%
df["Product_ID"]=df["Product_ID"].astype(object)
df.dtypes
# Out:
# Call_ID        object
# Sale           object
# Agent_ID       object
# Age             int64
# Product_ID     object
# Timezone        int64
# Phone_code    float64
# First_Name     object
# Last_Name      object
# Area_Code      object
# Gender         object
# Call_Count      int64
# dtype: object

# %%
df.Call_ID.unique().shape
# Out:
# (100000,)

# %%
df.Product_ID.unique().shape
# Out:
# (10,)

# %%
df.Agent_ID.unique().shape
# Out:
# (244,)

# %%
df.Timezone.unique().shape
# Out:
# (2,)

# %%
df.Timezone.unique()
# Out:
# array([2, 0], dtype=int64)

# %%
df[df.Timezone == 0]
# Out:
#         Call_ID   Sale Agent_ID  Age Product_ID  Timezone  Phone_code  \
# 7850    9563994   True     4702   66        147         0         NaN
# 11559   9383584   True     4219   56        146         0         NaN
# 18258   9663138  False     4992   80        147         0         NaN
# 18952   9200174  False     4992   66        145         0         NaN
# 19988   9663090  False     4219   25        147         0         NaN
# 23570  10462620  False     4219   75        151         0         NaN
# 28297   8794740  False     5002   78        143         0         NaN
# 30661   9844132   True     4304   31        148         0         NaN
# 31713  10476640  False     4219   55        151         0         NaN
# 32408   9380518    NaN     4219   52        146         0         NaN
# 35778  10138780   True     4734   78        149         0         NaN
# 40130  10024432    NaN     5310   48        149         0        37.0
# ...

# %%
df.isnull().sum()
# Out:
# Call_ID          0
# Sale            32
# Agent_ID      2315
# Age              0
# Product_ID       0
# Timezone         0
# Phone_code      28
# First_Name     682
# Last_Name      681
# Area_Code      460
# Gender           0
# Call_Count       0
# dtype: int64

# %%
df.Agent_ID.mode()
# Out:
# 0    4955
# Name: Agent_ID, dtype: object

# %%
df[df.Agent_ID == "4955"].shape
# Out:
# (1969, 12)

# %%
df.shape
# Out:
# (100000, 12)

# %%
df[df.Timezone == 2]
# Out:
#         Call_ID   Sale Agent_ID  Age Product_ID  Timezone  Phone_code  \
# 0       9545434  False     5265   42        147         2        37.0
# 1       9211206  False     5226   74        146         2        37.0
# 2       8873010  False     4452   35        144         2        37.0
# 3       9852034  False     5461   40        149         2        37.0
# 4       9416548  False     5298   26        147         2        37.0
# ...         ...    ...      ...  ...        ...       ...         ...
# 99995  10249682  False     5404   65        150         2        37.0
# 99996   8955506  False     5181   37        144         2        37.0
# 99997   9299394  False     5077   69        146         2        37.0
# 99998   9549720  False     5028   67        147         2        37.0
# 99999   9702206  False     5464   63        148         2        37.0
#
#       First_Name Last_Name Area_Code  Gender  Call_Count
# 0             Jk        Jk      2302    Male           1
# ...

# %%
df["Agent_ID"].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 99995    False
# 99996    False
# 99997    False
# 99998    False
# 99999    False
# Name: Agent_ID, Length: 100000, dtype: bool

# %%
df.Agent_ID.unique()
# Out:
# array(['5265', '5226', '4452', '5461', '5298', '5139', '4828', '5292',
#        '5044', '4912', '5230', '5002', '5053', '5312', '5214', '4926',
#        '5425', '5077', '5357', '4722', '5076', '4994', '5051', '5472',
#        '5296', '5207', '5386', '5209', '5208', '4866', nan, '5297',
#        '4995', '5313', '4958', '5073', '5028', '4804', '5341', '4876',
#        '5382', '5405', '5146', '5181', '4702', '5272', '4894', '5065',
#        '5403', '5459', '5424', '4971', '4677', '4748', '4899', '5266',
#        '5035', '5460', '4968', '4865', '5252', '5399', '5061', '4706',
#        '4955', '5220', '4956', '5216', '5032', '5406', '5224', '5462',
#        '4121', '5271', '5407', '5206', '5001', '5005', '5287', '5396',
#        '5464', '5294', '5052', '5423', '5421', '4827', '4483', '4709',
#        '5384', '5416', '5089', '5429', '5428', '5245', '5401', '4970',
#        '5366', '5381', '5367', '5302', '5368', '5106', '5495', '5393',
# ...

# %%
df[df.Agent_ID == "QUEUE5065"]
# Out:
#        Call_ID   Sale   Agent_ID  Age Product_ID  Timezone  Phone_code  \
# 589    9725038  False  QUEUE5065   76        148         2        37.0
# 12510  9673628  False  QUEUE5065   48        148         2        37.0
# 12608  9720364  False  QUEUE5065   32        148         2        37.0
# 17521  9711462  False  QUEUE5065   56        148         2        37.0
# 29033  9713930  False  QUEUE5065   42        148         2        37.0
# 30451  9678544  False  QUEUE5065   35        148         2        37.0
# 36874  9693564  False  QUEUE5065   45        148         2        37.0
# 46245  9689666  False  QUEUE5065   40        148         2        37.0
# 55463  9711148  False  QUEUE5065   62        148         2        37.0
# 69637  9720958  False  QUEUE5065   73        148         2        37.0
# 69813  9674536  False  QUEUE5065   52        148         2        37.0
# 73366  9709564  False  QUEUE5065   33        148         2        37.0
# ...

# %%
df[df.Area_Code == '?']
# Out:
# Empty DataFrame
# Columns: [Call_ID, Sale, Agent_ID, Age, Product_ID, Timezone, Phone_code, First_Name, Last_Name, Area_Code, Gender, Call_Count]
# Index: []

# %%
print(df.Phone_code.unique())
df["Phone_code"] = df["Phone_code"].replace(np.nan,37)
# Out:
# [37. nan]

# %%
df.Phone_code.mode()
# Out:
# 0    37.0
# Name: Phone_code, dtype: float64

# %%
new_df = df.drop(["Agent_ID","Phone_code","First_Name","Last_Name","Area_Code"],axis = 1)

# %%
new_df
# Out:
#         Call_ID   Sale  Age Product_ID  Timezone  Gender  Call_Count
# 0       9545434  False   42        147         2    Male           1
# 1       9211206  False   74        146         2    Male          10
# 2       8873010  False   35        144         2    Male           9
# 3       9852034  False   40        149         2    Male           6
# 4       9416548  False   26        147         2  Female          12
# ...         ...    ...  ...        ...       ...     ...         ...
# 99995  10249682  False   65        150         2  Female           1
# 99996   8955506  False   37        144         2  Female           6
# 99997   9299394  False   69        146         2    Male           1
# 99998   9549720  False   67        147         2    Male           1
# 99999   9702206  False   63        148         2  Female          15
#
# [100000 rows x 7 columns]

# %%
new_df.isnull().sum()
# Out:
# Call_ID        0
# Sale          32
# Age            0
# Product_ID     0
# Timezone       0
# Gender         0
# Call_Count     0
# dtype: int64

# %%
new_df[(new_df.Sale != False) & (new_df.Sale != True)].count()
# Out:
# Call_ID       32
# Sale           0
# Age           32
# Product_ID    32
# Timezone      32
# Gender        32
# Call_Count    32
# dtype: int64

# %%
new_df[(new_df.Sale != False) & (new_df.Sale != True)].head()
# Out:
#         Call_ID Sale  Age Product_ID  Timezone  Gender  Call_Count
# 3714   10240024  NaN   47        150         2  Others           1
# 6731    9865690  NaN   78        149         2  Others           3
# 8480   10234662  NaN   43        150         2  Others           1
# 11449   9896794  NaN   42        149         2  Female           2
# 14425   9860114  NaN   60        149         2  Others           2

# %%
new_df["Sale"] = new_df["Sale"].replace(np.nan,False)
new_df[(new_df.Sale != False) & (new_df.Sale != True)].head()
# Out:
# Empty DataFrame
# Columns: [Call_ID, Sale, Age, Product_ID, Timezone, Gender, Call_Count]
# Index: []

# %% [markdown]
# # By Male Senior Citizens

# %%
print(new_df[(new_df.Gender == "Male") & (new_df.Age >= 60)].head())
print(new_df[(new_df.Gender == "Male") & (new_df.Age >= 60)].count())
# Out:
#      Call_ID   Sale  Age Product_ID  Timezone Gender  Call_Count
# 1    9211206  False   74        146         2   Male          10
# 9   10216124   True   72        150         2   Male           1
# 15  10271460  False   79        151         2   Male           1
# 16   9222054  False   63        146         2   Male          12
# 22  10305716  False   70        151         2   Male           1
# Call_ID       19589
# Sale          19589
# Age           19589
# Product_ID    19589
# Timezone      19589
# Gender        19589
# Call_Count    19589
# dtype: int64

# %%
print(new_df[(new_df.Gender == "Male") & (new_df.Age > 30) & (new_df.Age < 60)].head())
print(new_df[(new_df.Gender == "Male") & (new_df.Age > 30) & (new_df.Age < 60)].count())
# Out:
#     Call_ID   Sale  Age Product_ID  Timezone Gender  Call_Count
# 0   9545434  False   42        147         2   Male           1
# 2   8873010  False   35        144         2   Male           9
# 3   9852034  False   40        149         2   Male           6
# 13  9899362   True   53        149         2   Male           1
# 17  8927484  False   33        144         2   Male           7
# Call_ID       26880
# Sale          26880
# Age           26880
# Product_ID    26880
# Timezone      26880
# Gender        26880
# Call_Count    26880
# dtype: int64

# %%
print(new_df[(new_df.Gender == "Male") & (new_df.Age <= 30)].head())
print(new_df[(new_df.Gender == "Male") & (new_df.Age <= 30)].count())
# Out:
#       Call_ID   Sale  Age Product_ID  Timezone Gender  Call_Count
# 19   10237446  False   25        150         2   Male           1
# 48    9181376  False   27        145         2   Male           5
# 88    9771870  False   28        148         2   Male          15
# 135   9673328  False   30        148         2   Male           1
# 143   8629858  False   28        143         2   Male           9
# Call_ID       5533
# Sale          5533
# Age           5533
# Product_ID    5533
# Timezone      5533
# Gender        5533
# Call_Count    5533
# dtype: int64

# %%
print(new_df[(new_df.Gender == "Female") & (new_df.Age >= 60)].head())
print(new_df[(new_df.Gender == "Female") & (new_df.Age >= 60)].count())
# Out:
#     Call_ID   Sale  Age Product_ID  Timezone  Gender  Call_Count
# 7   9105514  False   70        145         2  Female           9
# 11  9944378  False   73        149         2  Female           1
# 14  9302198  False   67        146         2  Female           7
# 21  9538208  False   70        147         2  Female           1
# 43  8544466  False   65        142         2  Female           7
# Call_ID       17583
# Sale          17583
# Age           17583
# Product_ID    17583
# Timezone      17583
# Gender        17583
# Call_Count    17583
# dtype: int64

# %%
print(new_df[(new_df.Gender == "Female") & (new_df.Age > 30) & (new_df.Age < 60)].head())
print(new_df[(new_df.Gender == "Female") & (new_df.Age > 30) & (new_df.Age < 60)].count())
# Out:
#      Call_ID   Sale  Age Product_ID  Timezone  Gender  Call_Count
# 5   10189322  False   33        150         2  Female           1
# 6   10277850  False   33        151         2  Female           3
# 8    8663012  False   41        143         2  Female           9
# 10   9857654  False   34        149         2  Female           1
# 25   9139012  False   55        145         2  Female          11
# Call_ID       24402
# Sale          24402
# Age           24402
# Product_ID    24402
# Timezone      24402
# Gender        24402
# Call_Count    24402
# dtype: int64

# %%
print(new_df[(new_df.Gender == "Female") & (new_df.Age <= 30)].head())
print(new_df[(new_df.Gender == "Female") & (new_df.Age <= 30)].count())
# Out:
#      Call_ID   Sale  Age Product_ID  Timezone  Gender  Call_Count
# 4    9416548  False   26        147         2  Female          12
# 12   9079430  False   30        145         2  Female           3
# 37   9366710  False   29        146         2  Female           2
# 53   9744686  False   30        148         2  Female           2
# 109  9531588  False   25        147         2  Female           2
# Call_ID       5011
# Sale          5011
# Age           5011
# Product_ID    5011
# Timezone      5011
# Gender        5011
# Call_Count    5011
# dtype: int64

# %%
print(new_df[(new_df.Gender == "Others") & (new_df.Age >= 60)].head())
print(new_df[(new_df.Gender == "Others") & (new_df.Age >= 60)].count())
# Out:
#        Call_ID   Sale  Age Product_ID  Timezone  Gender  Call_Count
# 129    9958446  False   77        149         2  Others           3
# 973   10189162  False   60        150         2  Others           2
# 1023   9673236  False   64        148         2  Others          10
# 1305  10147474  False   61        150         2  Others           2
# 1905   9185328  False   61        145         2  Others           3
# Call_ID       366
# Sale          366
# Age           366
# Product_ID    366
# Timezone      366
# Gender        366
# Call_Count    366
# dtype: int64

# %%
print(new_df[(new_df.Gender == "Others") & (new_df.Age > 30) & (new_df.Age < 60)].head())
print(new_df[(new_df.Gender == "Others") & (new_df.Age > 30) & (new_df.Age < 60)].count())
# Out:
#       Call_ID   Sale  Age Product_ID  Timezone  Gender  Call_Count
# 453  10193510  False   42        150         2  Others           1
# 637   9193992  False   34        145         2  Others           3
# 742   9196950   True   56        145         2  Others           4
# 746   9197334  False   56        145         2  Others           1
# 902   9191266  False   45        145         2  Others           4
# Call_ID       529
# Sale          529
# Age           529
# Product_ID    529
# Timezone      529
# Gender        529
# Call_Count    529
# dtype: int64

# %%
print(new_df[(new_df.Gender == "Others") & (new_df.Age <= 30)].head())
print(new_df[(new_df.Gender == "Others") & (new_df.Age <= 30)].count())
# Out:
#        Call_ID   Sale  Age Product_ID  Timezone  Gender  Call_Count
# 241    9197350  False   25        145         2  Others           1
# 708   10143650  False   25        150         2  Others           3
# 1713   9175944  False   29        145         2  Others           4
# 1930  10227970  False   28        150         2  Others           3
# 3504  10173220  False   30        150         2  Others           2
# Call_ID       107
# Sale          107
# Age           107
# Product_ID    107
# Timezone      107
# Gender        107
# Call_Count    107
# dtype: int64

# %% [raw]
# # From above we can state that Males,Females and others all from the age group between 30 and 60 are more interested
# # Age <= 30 in all genders are quiet less interested
# # Age >= 60 in all genders are quiet more interested than Age <= 30 and less interested than age group between 30 and 60

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Call_ID     100000 non-null  object
#  1   Sale        100000 non-null  bool
#  2   Age         100000 non-null  int64
#  3   Product_ID  100000 non-null  object
#  4   Timezone    100000 non-null  int64
#  5   Gender      100000 non-null  object
#  6   Call_Count  100000 non-null  int64
# dtypes: bool(1), int64(3), object(3)
# memory usage: 4.7+ MB

# %%
new_df.dtypes
# Out:
# Call_ID       object
# Sale            bool
# Age            int64
# Product_ID    object
# Timezone       int64
# Gender        object
# Call_Count     int64
# dtype: object

# %%
new_df[new_df.Timezone == 0]
# In Timezone 0 , Gender : others are more as compared to males
# Out:
#         Call_ID   Sale  Age Product_ID  Timezone  Gender  Call_Count
# 7850    9563994   True   66        147         0  Others           2
# 11559   9383584   True   56        146         0  Others           1
# 18258   9663138  False   80        147         0  Others           2
# 18952   9200174  False   66        145         0    Male           4
# 19988   9663090  False   25        147         0  Others           2
# 23570  10462620  False   75        151         0  Others           1
# 28297   8794740  False   78        143         0  Others           3
# 30661   9844132   True   31        148         0    Male           1
# 31713  10476640  False   55        151         0  Others           1
# 32408   9380518  False   52        146         0  Others           1
# 35778  10138780   True   78        149         0  Others           1
# 40130  10024432  False   48        149         0  Others           2
# 42819  10435304   True   29        151         0  Others           1
# ...

# %%
sns.relplot(x="Gender",y="Call_Count",data=new_df)

# %%
print(new_df[new_df.Gender == "Male"].count())
print(new_df[new_df.Gender == "Female"].count())
print(new_df[new_df.Gender == "Others"].count())

#Males are more as compared to females and others
# Males = 52002
# Females = 46996
# Others = 1002
# Out:
# Call_ID       52002
# Sale          52002
# Age           52002
# Product_ID    52002
# Timezone      52002
# Gender        52002
# Call_Count    52002
# dtype: int64
# Call_ID       46996
# Sale          46996
# Age           46996
# Product_ID    46996
# Timezone      46996
# Gender        46996
# Call_Count    46996
# dtype: int64
# Call_ID       1002
# Sale          1002
# Age           1002
# Product_ID    1002
# Timezone      1002
# Gender        1002
# Call_Count    1002
# dtype: int64
